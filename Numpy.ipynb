# %% [markdown]
# <a href="https://colab.research.google.com/github/mendoncalan/Data_structure_python/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arrays vs Lists

# %%
import numpy as np

# %%
L= [1,2,3]

# %%
A= np.array([1,2,3])

# %%
for e in L:
  print(e)
# Out:
# 1
# 2
# 3

# %%
for e in A:
  print(e)
# Out:
# 1
# 2
# 3

# %% [markdown]
# Adding New item to the list

# %%
L.append(4)

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
A.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1332050475.py in <cell line: 0>()
# ----> 1 A.append(4)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %% [markdown]
# *Size of Lsit can change but the Size of Numpy Array is fixed*

# %%
L +[5]
# Out:
# [1, 2, 3, 4, 5]

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
A+np.array([4]) # it will add 4 to each element in A
# Out:
# array([5, 6, 7])

# %%
A + np.array([4,5,6])#it will do vector addition
# Out:
# array([5, 7, 9])

# %%
2* A # it multip 2 to alll the element in np.array
# Out:
# array([2, 4, 6])

# %%
2 *L # it will repeat L element 2 times
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
# Add 3 to all the element in L
L2=[]
for e in L:
  L2.append(e+3)

# %%
L2
# Out:
# [4, 5, 6, 7]

# %%
l2= [e+3 for e in L]# List comprehension

# %%
L2
# Out:
# [4, 5, 6, 7]

# %%
L2 =[]
for e in L:
  L2.append(e**2)

# %%
L2
# Out:
# [1, 4, 9, 16]

# %%
A**2
# Out:
# array([1, 4, 9])

# %%
np.sqrt(A)
# Out:
# array([1.        , 1.41421356, 1.73205081])

# %%
np.log(A)
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %%
np.exp(A)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
np.tanh(A)
# Out:
# array([0.76159416, 0.96402758, 0.99505475])

# %% [markdown]
# The Dot Product

# %%
a = np.array([1,2])

# %%
b= np.array([3,4])

# %%
dot =0
for e , f in zip(a,b): # zip() function is a python built in function for combining Multiple iterable object like List, tuples or string into a single iterable Tuples. https://www.codecademy.com/article/python-zip-function
  dot+=e*f

# %%
dot
# Out:
# np.int64(11)

# %%
dot=0
for i in range(len(a)):
  dot+= a[i]*b[i]

# %%
dot
# Out:
# np.int64(11)

# %%
a*b
# Out:
# array([3, 8])

# %%
np.sum(a*b)
# Out:
# np.int64(11)

# %%
(a*b).sum()
# Out:
# np.int64(11)

# %%
np.dot(a,b)
# Out:
# np.int64(11)

# %%
a.dot(b)
# Out:
# np.int64(11)

# %%
a @ b
# Out:
# np.int64(11)

# %% [markdown]
# **Matrices**

# %%
L = [[1,2],[3,4]]
L
# Out:
# [[1, 2], [3, 4]]

# %%
for i in range( 0, len(L)):
  for j in range(0, len(L[i])):
    print(L[i][j])
# Out:
# 1
# 2
# 3
# 4

# %%
A = np.array([[1,2],[3,4]])
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A[:,0]
# Out:
# array([1, 3])

# %%
A.T #It give transpose of Matrix A
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
np.exp(A)
# Out:
# array([[ 2.71828183,  7.3890561 ],
#        [20.08553692, 54.59815003]])

# %%
np.exp(L)
# Out:
# array([[ 2.71828183,  7.3890561 ],
#        [20.08553692, 54.59815003]])

# %%
B= np.array([[2,4,6],[3,5,6]])
B
# Out:
# array([[2, 4, 6],
#        [3, 5, 6]])

# %%
A.dot(B)
# Out:
# array([[ 8, 14, 18],
#        [18, 32, 42]])

# %%
A.dot(B.T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1994487925.py in <cell line: 0>()
# ----> 1 A.dot(B.T)
#
# ValueError: shapes (2,2) and (3,2) not aligned: 2 (dim 1) != 3 (dim 0)

# %% [markdown]
# Linear Systems

# %%
a =np.array([[1,1],[1.5,4]])
b= np.array([2200,5050])

# %%
np.linalg.solve(a,b)
# Out:
# array([1500.,  700.])

# %% [markdown]
# Generating DAta

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
10*np.ones((2,3))
# Out:
# array([[10., 10., 10.],
#        [10., 10., 10.]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.random.random((2,3))
# Out:
# array([[0.34079951, 0.75947186, 0.5257967 ],
#        [0.70691155, 0.98121872, 0.96043236]])

# %%
np.random.randn(2,3)# to get number from Normal distribution
# Out:
# array([[-0.00849807,  2.46500418,  0.31619577],
#        [ 0.52925558, -0.93178079,  0.09997658]])

# %%
R = np.random.randn(10000)

# %%
R.mean()
# Out:
# np.float64(-0.0008035685748674076)

# %%
np.mean(R)
# Out:
# np.float64(-0.0008035685748674076)

# %%
R.var()
# Out:
# np.float64(0.9995362106399767)

# %%
R.std()
# Out:
# np.float64(0.9997680784261801)

# %%
R = np.random.randn(10000,3)

# %%
R.mean(axis=0)
# Out:
# array([0.00038596, 0.00331604, 0.00597545])

# %%
R.mean(axis=1)
# Out:
# array([ 0.01300305,  0.24988911,  0.04232417, ..., -0.67437349,
#         0.5879251 , -0.68378091])

# %%
np.cov(R)
# Out:
# array([[ 3.77952889,  0.75234454, -0.99911095, ..., -1.28395454,
#         -0.7229837 ,  1.02663232],
#        [ 0.75234454,  0.74067184, -0.04800148, ..., -0.8315012 ,
#          0.64750022,  0.77004822],
#        [-0.99911095, -0.04800148,  0.30263747, ...,  0.19235941,
#          0.39319388, -0.12694911],
#        ...,
#        [-1.28395454, -0.8315012 ,  0.19235941, ...,  0.99748457,
#         -0.52573026, -0.90009747],
#        [-0.7229837 ,  0.64750022,  0.39319388, ..., -0.52573026,
#          1.19825226,  0.56125076],
#        [ 1.02663232,  0.77004822, -0.12694911, ..., -0.90009747,
#          0.56125076,  0.82040682]])

# %%
np.cov(R).shape
# Out:
# (10000, 10000)

# %%
(R.T).shape
# Out:
# (3, 10000)

# %%
np.cov(R.T)
# Out:
# array([[ 1.00981873,  0.00285752, -0.00623937],
#        [ 0.00285752,  1.01404116,  0.01663934],
#        [-0.00623937,  0.01663934,  1.01028209]])

# %%
np.random.randint(0,10,size=(3,3))
# Out:
# array([[0, 8, 7],
#        [4, 6, 6],
#        [2, 8, 9]])

# %%
np.random.choice(10, size=(3,3))
# Out:
# array([[1, 2, 2],
#        [5, 7, 1],
#        [0, 3, 2]])
